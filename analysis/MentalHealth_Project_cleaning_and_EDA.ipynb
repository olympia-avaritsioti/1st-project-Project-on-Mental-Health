# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'Mental Health Dataset.csv')

# %%
df.shape
# Out:
# (292364, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                292364 non-null  object
#  1   Gender                   292364 non-null  object
#  2   Country                  292364 non-null  object
#  3   Occupation               292364 non-null  object
#  4   self_employed            287162 non-null  object
#  5   family_history           292364 non-null  object
#  6   treatment                292364 non-null  object
#  7   Days_Indoors             292364 non-null  object
#  8   Growing_Stress           292364 non-null  object
#  9   Changes_Habits           292364 non-null  object
#  10  Mental_Health_History    292364 non-null  object
#  11  Mood_Swings              292364 non-null  object
#  12  Coping_Struggles         292364 non-null  object
#  13  Work_Interest            292364 non-null  object
#  14  Social_Weakness          292364 non-null  object
#  15  mental_health_interview  292364 non-null  object
#  16  care_options             292364 non-null  object
# dtypes: object(17)
# memory usage: 37.9+ MB

# %%
df.describe()
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# count            292364  292364         292364     292364        287162
# unique              580       2             35          5             2
# top     8/27/2014 11:43    Male  United States  Housewife            No
# freq               2384  239850         171308      66351        257994
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# count          292364    292364       292364         292364         292364
# unique              2         2            5              3              3
# top                No       Yes    1-14 days          Maybe            Yes
# freq           176832    147606        63548          99985         109523
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# count                 292364      292364           292364        292364
# unique                     3           3                2             3
# top                       No      Medium               No            No
# freq                  104018      101064           154328        105843
#
#        Social_Weakness mental_health_interview care_options
# count           292364                  292364       292364
# unique               3                       3            3
# top              Maybe                      No           No
# freq            103393                  232166       118886

# %% [markdown]
# --------------------------------------------------------
# DATA CLEANINIG PROCESS!
# ---------------------------------------------------------

# %%
#inserting a new column called 
df.rename(columns = {'Timestamp':'Date'},inplace=True)
df
# Out:
#                    Date  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0                  No       Yes    1-14 days            Yes             No
# 1                 Yes       Yes    1-14 days            Yes             No
# 2                 Yes       Yes    1-14 days            Yes             No
# 3                 Yes       Yes    1-14 days            Yes             No
# 4                 Yes       Yes    1-14 days            Yes             No
# ...               ...       ...          ...            ...            ...
# 292359            Yes       Yes   15-30 days             No          Maybe
# 292360            Yes       Yes   15-30 days             No          Maybe
# 292361            Yes        No   15-30 days             No          Maybe
# 292362            Yes       Yes   15-30 days             No          Maybe
# 292363            Yes       Yes   15-30 days             No          Maybe
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                        Yes      Medium               No            No
# 1                        Yes      Medium               No            No
# 2                        Yes      Medium               No            No
# 3                        Yes      Medium               No            No
# 4                        Yes      Medium               No            No
# ...                      ...         ...              ...           ...
# 292359                    No         Low              Yes            No
# 292360                    No         Low              Yes            No
# 292361                    No         Low              Yes            No
# 292362                    No         Low              Yes            No
# 292363                    No         Low              Yes            No
#
#        Social_Weakness mental_health_interview care_options
# 0                  Yes                      No     Not sure
# 1                  Yes                      No           No
# 2                  Yes                      No          Yes
# 3                  Yes                   Maybe          Yes
# 4                  Yes                      No          Yes
# ...                ...                     ...          ...
# 292359           Maybe                   Maybe     Not sure
# 292360           Maybe                      No          Yes
# 292361           Maybe                      No           No
# 292362           Maybe                      No          Yes
# 292363           Maybe                      No          Yes
#
# [292364 rows x 17 columns]

# %%
#convert date[object] to date[datetime64[ns]]
df['Date'] = pd.to_datetime(df['Date'])

# %%
#adding a month/year column
df.insert(1, column = 'Month', value=df['Date'].dt.month)
df.insert(2, column = 'Year', value=df['Date'].dt.year)

# %%
df.set_index(['Country','Gender'])
# Out:
#                                     Date  Month  Year Occupation  \
# Country       Gender
# United States Female 2014-08-27 11:29:00      8  2014  Corporate
#               Female 2014-08-27 11:31:00      8  2014  Corporate
#               Female 2014-08-27 11:32:00      8  2014  Corporate
#               Female 2014-08-27 11:37:00      8  2014  Corporate
#               Female 2014-08-27 11:43:00      8  2014  Corporate
# ...                                  ...    ...   ...        ...
#               Male   2015-07-27 23:25:00      7  2015   Business
# South Africa  Male   2015-08-17 09:38:00      8  2015   Business
# United States Male   2015-08-25 19:59:00      8  2015   Business
#               Male   2015-09-26 01:07:00      9  2015   Business
#               Male   2016-02-01 23:04:00      2  2016   Business
#
#                      self_employed family_history treatment Days_Indoors  \
# Country       Gender
# United States Female           NaN             No       Yes    1-14 days
#               Female           NaN            Yes       Yes    1-14 days
#               Female           NaN            Yes       Yes    1-14 days
#               Female            No            Yes       Yes    1-14 days
#               Female            No            Yes       Yes    1-14 days
# ...                            ...            ...       ...          ...
#               Male             Yes            Yes       Yes   15-30 days
# South Africa  Male              No            Yes       Yes   15-30 days
# United States Male              No            Yes        No   15-30 days
#               Male              No            Yes       Yes   15-30 days
#               Male              No            Yes       Yes   15-30 days
#
#                      Growing_Stress Changes_Habits Mental_Health_History  \
# Country       Gender
# United States Female            Yes             No                   Yes
#               Female            Yes             No                   Yes
#               Female            Yes             No                   Yes
#               Female            Yes             No                   Yes
#               Female            Yes             No                   Yes
# ...                             ...            ...                   ...
#               Male               No          Maybe                    No
# South Africa  Male               No          Maybe                    No
# United States Male               No          Maybe                    No
#               Male               No          Maybe                    No
#               Male               No          Maybe                    No
#
#                      Mood_Swings Coping_Struggles Work_Interest  \
# Country       Gender
# United States Female      Medium               No            No
#               Female      Medium               No            No
#               Female      Medium               No            No
#               Female      Medium               No            No
#               Female      Medium               No            No
# ...                          ...              ...           ...
#               Male           Low              Yes            No
# South Africa  Male           Low              Yes            No
# United States Male           Low              Yes            No
#               Male           Low              Yes            No
#               Male           Low              Yes            No
#
#                      Social_Weakness mental_health_interview care_options
# Country       Gender
# United States Female             Yes                      No     Not sure
#               Female             Yes                      No           No
#               Female             Yes                      No          Yes
#               Female             Yes                   Maybe          Yes
#               Female             Yes                      No          Yes
# ...                              ...                     ...          ...
#               Male             Maybe                   Maybe     Not sure
# South Africa  Male             Maybe                      No          Yes
# United States Male             Maybe                      No           No
#               Male             Maybe                      No          Yes
#               Male             Maybe                      No          Yes
#
# [292364 rows x 17 columns]

# %%
#Counting Yes/no answers
counts = df['self_employed'].value_counts(dropna=True)
counts
# Out:
# No     257994
# Yes     29168
# Name: self_employed, dtype: int64

# %%
#Percentage of Yes/No answers
percentages = df['self_employed'].value_counts(normalize=True, dropna=True)
percentages
# Out:
# No     0.898427
# Yes    0.101573
# Name: self_employed, dtype: float64

# %%
#Filling NaNs

# %%
# creating a dictionary with the percentages of Yes/No answers
perc_self_employed = percentages.to_dict() 
print(perc_self_employed)
# Out:
# {'No': 0.8984266720527089, 'Yes': 0.10157332794729107}

# %%
#Nans
nans = df['self_employed'].isna()
print(nans.sum())
# Out:
# 5202

# %%
df.loc[nans, 'self_employed'] = np.random.choice(
    list(perc_self_employed.keys()),
    size=nans.sum(),
    p=list(perc_self_employed.values())
)

# %%
#df.groupby(['Country','Gender']).count().sort_values('Gender',ascending=False)#.plot.bar(figsize=(10,8))

# %%
counts1 = df['self_employed'].value_counts(dropna=True)
counts1
# Out:
# No     262661
# Yes     29703
# Name: self_employed, dtype: int64

# %%
percentages1 = df['self_employed'].value_counts(normalize=True, dropna=True)
percentages1
# Out:
# No     0.898404
# Yes    0.101596
# Name: self_employed, dtype: float64

# %%
df
# Out:
#                       Date  Month  Year  Gender        Country Occupation  \
# 0      2014-08-27 11:29:00      8  2014  Female  United States  Corporate
# 1      2014-08-27 11:31:00      8  2014  Female  United States  Corporate
# 2      2014-08-27 11:32:00      8  2014  Female  United States  Corporate
# 3      2014-08-27 11:37:00      8  2014  Female  United States  Corporate
# 4      2014-08-27 11:43:00      8  2014  Female  United States  Corporate
# ...                    ...    ...   ...     ...            ...        ...
# 292359 2015-07-27 23:25:00      7  2015    Male  United States   Business
# 292360 2015-08-17 09:38:00      8  2015    Male   South Africa   Business
# 292361 2015-08-25 19:59:00      8  2015    Male  United States   Business
# 292362 2015-09-26 01:07:00      9  2015    Male  United States   Business
# 292363 2016-02-01 23:04:00      2  2016    Male  United States   Business
#
#        self_employed family_history treatment Days_Indoors Growing_Stress  \
# 0                 No             No       Yes    1-14 days            Yes
# 1                 No            Yes       Yes    1-14 days            Yes
# 2                 No            Yes       Yes    1-14 days            Yes
# 3                 No            Yes       Yes    1-14 days            Yes
# 4                 No            Yes       Yes    1-14 days            Yes
# ...              ...            ...       ...          ...            ...
# 292359           Yes            Yes       Yes   15-30 days             No
# 292360            No            Yes       Yes   15-30 days             No
# 292361            No            Yes        No   15-30 days             No
# 292362            No            Yes       Yes   15-30 days             No
# 292363            No            Yes       Yes   15-30 days             No
#
#        Changes_Habits Mental_Health_History Mood_Swings Coping_Struggles  \
# 0                  No                   Yes      Medium               No
# 1                  No                   Yes      Medium               No
# 2                  No                   Yes      Medium               No
# 3                  No                   Yes      Medium               No
# 4                  No                   Yes      Medium               No
# ...               ...                   ...         ...              ...
# 292359          Maybe                    No         Low              Yes
# 292360          Maybe                    No         Low              Yes
# 292361          Maybe                    No         Low              Yes
# 292362          Maybe                    No         Low              Yes
# 292363          Maybe                    No         Low              Yes
#
#        Work_Interest Social_Weakness mental_health_interview care_options
# 0                 No             Yes                      No     Not sure
# 1                 No             Yes                      No           No
# 2                 No             Yes                      No          Yes
# 3                 No             Yes                   Maybe          Yes
# 4                 No             Yes                      No          Yes
# ...              ...             ...                     ...          ...
# 292359            No           Maybe                   Maybe     Not sure
# 292360            No           Maybe                      No          Yes
# 292361            No           Maybe                      No           No
# 292362            No           Maybe                      No          Yes
# 292363            No           Maybe                      No          Yes
#
# [292364 rows x 19 columns]
